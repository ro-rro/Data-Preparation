# %% [markdown]
# # Week 1 & 2 Coding Assignment:
#
# Author: Rosie Navarro
#
# Date: 10 September 2026
#
# Description:

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# The following creates a list of numbers that I chose.

# %%
numbers = [10, 1, 15, 5, 7, 23, 2, 6]
print("Number list is:", numbers)
# Out:
# Number list is: [10, 1, 15, 5, 7, 23, 2, 6]

# %%
print("Numbers in the list:")

for number in numbers:
    print(number)
# Out:
# Numbers in the list:
# 10
# 1
# 15
# 5
# 7
# 23
# 2
# 6

# %%
numbers.sort()

print(numbers)
# Out:
# [1, 2, 5, 6, 7, 10, 15, 23]

# %%
for i in range(5):
    numbers.append(random.randint(1,1000))

# %%
numbers.sort()

print("Final Number list:", numbers)
# Out:
# Final Number list: [1, 2, 5, 6, 7, 10, 15, 23, 349, 617, 779, 912, 965]
